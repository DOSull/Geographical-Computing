# %% [markdown]
# #### GISC 425 T1 2020
# # Web scraping in `python`
# There's a lot of data out there on the web these days, much of it spatial in nature. How can we get those data into a form we can use in GIS or other geospatial tools? That's what this week's lab materials focus on.
#
# To get there, we need to understand a little bit about how websites and web pages work.
#
# ## What's in a web page
# OK... let's take a look at a [simple web page](https://southosullivan.com/gisc425/other/simple-web-page.html). This is an example of very simple web map.
#
# In the browser you are viewing it with, do something like right-click **View page source**.
#
# You should see the following:

# %% [markdown]
# ```
# <!DOCTYPE html>
#
# <html>
#     <head>
#         <title>A very simple web page</title>
#     </head>
#
#     <body>
#         <h1>My first web page
#         </h1>
#         <p>This page demonstrates some <i>very</i> basic HTML for use in my classes.
#         </p>
#         <p>This page was written by <a href=
#         "https://southosullivan.com/geodos">Prof David O'Sullivan</a>.
#         </p>
#         <p>David is from Ireland.  Sometimes, he misses Ireland's glorious summers, like the one in
#         this picture.
#         </p>
#         <img src="muckish.jpg" width=640>
#         <figcaption>Yes, that picture really was taken in August</figcaption>
#         <p>That's Muckish Mountain in Donegal.  Here is a map.</p>
#         <iframe src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d51581.682424507155!2d-8.022036861268594!3d55.097443300030626!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x0000000000000000%3A0xd25d3a3fef4d920c!2sMt.+Muckish!5e0!3m2!1sen!2sus!4v1441395150485" width="400" height="300" frameborder="0" style="border:0" allowfullscreen></iframe>
#         <p>The picture was taken from <a href=
# "https://www.google.com/maps/@55.214797,-7.978438,3a,75y,205.64h,91.69t/data=!3m4!1e1!3m2!1ssdYiz3D8tz6atCSdR9200w!2e0?hl=en">roughly here</a>.  The google car got better weather than I did.
#         </p>
#     </body>
# </html>
# ```

# %% [markdown]
# Although, what you see will be syntax-coloured to help understand it a little better.
#
# The key thing from our present perspective is to note that there is *a tree like structure* to this page.
#
# At the 'trunk' of the tree is the whole page denoted by `<HTML></HTML>` **tags**.
#
# Nested below this are the `<head></head>` and `<body></body>` **elements**.
#
# Inside each of these are other elements, headings, paragraphs, an image, a figure caption, and something called an iframe, inside of which is the map.
#
# This is an exceedingly simple web page.

# %% [markdown]
# ## Something a bit more complicated
# So now look at [this page](https://southosullivan.com/gisc422/interpolation/#/).
#
# Let's again, take a closer look, and also examine it with your browser's **web console** tools.
#
# **I'll talk you through this**.

# %% [markdown]
# ## Summing things up
# Web pages are assembled from several different pieces
#
# 1. **Hyper Text Markup Language** (HTML) tags describe the structure of the page using hierarchically  nested tags that defined the *elements* which make up the page.
# 2. **Cascading Style Sheets** (CSS) determine how various elements in a page should be displayed.
# 3. Client-side code in **JavaScript** which is often used to build interactive elements in the page, which are responsive to the page's readers.
#
# There is a fourth 'hidden' element to most pages, which is the server-side database(s) used to populate typical pages with requested information. On human-facing pages, this part of the process is generally handled by a combination of client-side interface elements that obtain information from users (search terms and so on), and form these into query strings that are decoded into database queries on the server-side. Responses from the database populate the page that is eventually seen by a user.
#
# [Google](https://google.com) and [Google maps](https://maps.google.com) and [Let Me Google That For You](https://lmgtfy.com) provide simple examples of query strings.

# %% [markdown]
# ## So much for simple
# The simple structure of the web pages we have looked at is about the limit of what can be built by hand by a semi-skilled human (like me...). Almost all web pages today are assembled in automated fashion. Take a look for example at [this page](https://www.pbtech.co.nz/product/NETHUA8372/Huawei-E8372-4GLTE-USB-Mobile-Wi-Fi-Hotspot-with-S). Click on another page at the same site, and compare the code you can see in the web console inspector. Or here is [another example](https://en.wikipedia.org/wiki/HTML).
#
# The point is that every page has a similar structure, and it is this structure that we can use to automate the process of obtaining useable data from webpages.

# %% [markdown]
# ## But... before we go there
# OK... it's important to realise that there are situations where automation may not be the point. There are two extremes to this.
#
# **First**, you might just be interested in a particular dataset in a once-off fashion. Here's an example [the New Zealand AED map](https://aedlocations.co.nz/) of how that can work.
#
# **Alternatively**, the website in question may have an API, which allows you to make queries in an organised way. Many companies publish APIs because they _want_ other websites to be able to link to theirs in an interactive way. Here's [an example](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html). There are downsides to using an API. For a start, they might not be free. Or at any rate, the free version may be limited in some way. In many cases you are rate limited to the number of searches allowed in a given time period, and also required to authenticate (i.e. you need an account with the service). Furthermore, even premium versions may not offer all the functionality you would like. On the other hand, they are generally well documented, and greatly simplify the business of regularly pulling data from websites of interest.
#
# A middle ground is that you might find that others have written tools to interface with popular APIs. For see this list of [python flickr related projects on github](https://github.com/search?q=python+flickr).

# %% [markdown]
# ## Getting serious about web scraping
# Assuming none of the above options are available or useful for whatever reason, you may want to develop code to *scrape* data from websites. There may be additional advantages to going down this path: no registration necessary, no rate limiting. Anything viewable on a website can be scraped. Having said that:
#
# * Check terms and conditions before scraping
# * Be nice: it's pretty easy to inadvertently launch a denial of service attack on a website if you hit it too often with too many requests
# * Website change all the time, so scraping code that works one day might break at any moment; be prepared to have to continually update your code
#
# Getting into web scraping requires us to delve a bit more deeply into that tree structure of web pages that I have already mentioned. That means...

# %% [markdown]
# ## ... getting to know the DOM
# Like everything else in computing, that tree-like structure has an acronym. It is the key idea behind the **Document Object Model** by which web pages are organised.
#
# The DOM is a language independent API that allows manipulation of the contents of a document such that its contents and appearance can be changed programmatically. It allows automatic navigation and search of the structure of a document.
#
# So, how does it work.
# ### A tree
# Every document is organised as a nested set of *elements* in tree-like fashion.
#
# <img src='dom.png'>
#
# **Source**: [DOM and JQuery](https://cs.wellesley.edu/~cs110/reading/DOM-JQ.html)
#
# This nested structure, and the fact that all the pages on a given site of a given kind will have the same structure, makes it possible to write code to *traverse* the tree and extract the elements of interest, including any data they may contain.
#
# Modern browsers *parse* HTML into the DOM format, and then render the webpage. In web scraping we use the same information the browsers uses to render the page to figure out which pieces of the page we want to scrape.

# %% [markdown]
# ### A tree with labels
# The HTML elements in the DOM tree usually have three components.
#
# First there are **tags** which designate the beginning and end of the element. These are the opening `<tagname>` and closing `</tagname>` chunks we have seen all over the web page source material we have been looking at.
#
# Second tags have associated with them **attributes** and **content**. The content is all the material (which may include additional nested elements) between the tag start and end markers. The attributes are additional information describing the tag (in effect data about the tag itself.
#
# Some common HTML tags.
#
#  Tag   | Usage
#  --- | -----
# `<html>` | Designates a HTML document
# `<head><body>` | The header and main body of a document
# `<div>` | A general container for content used to structure a document into sections
# `<span>` | A container for inline material, often used to mark particular items
# `<h1><h2><h3>...` | Headings (up to 6 levels)
# `<ol><ul><li>` | Lists of various kinds
# `<a>` | Anchors - most often used for hyperlinks
# `<p>` | Paragraphs

# %% [markdown]
# ### More labels
# In addition to the tags themselves, and any inbuilt attributes they might have (such as, e.g. `<a href="..">` where href is an expected attribute of an anchor tag, most web pages have addition `class` or `id` tags that web designers use in tandem with CSS to control the format of the web page.
#
# We aren't too concerned about the details of this (if you want to know more, then learn web design...). For our purposes, the important thing about the CSS class and id features is that they may make it easier to search for particular items of interest on a page.
#
# So the basic idea is to investigate the web page you are interested in scraping, using the web tools, particularly the inspector, to identify the particular combination of tag, class and id selectors associated with the information you are interested in. Hopefully there is a pattern, and hopefully that will enable automated collection of the data.

# %% [markdown]
# ## Enough already, show us some code!
# OK... to do this we need to install a new module.

# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/osullid3/anaconda3/envs/g425-20/lib/python3.7/site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /home/osullid3/anaconda3/envs/g425-20/lib/python3.7/site-packages (from BeautifulSoup4) (1.9.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# [`BeautifulSoup`](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) is a python module that makes it fairly easy to parse the DOM of a web page, and thus assemble the information of interest in an automated way. Once installed, we need to import it

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Now we need to point it at some content. To do this we use another module, called [`requests`](http://docs.python-requests.org/en/latest/user/quickstart/)

# %%
import requests

# %% [markdown]
# Requests allows you to get all the information from a URL. It's pretty easy to use.

# %%
simplepage = requests.get('http://southosullivan.com/gisc425/other/simple-web-page.html')
simplepage.text
# Out:
# '<!DOCTYPE html>\n<html style="height:100%">\n<head>\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" >\n<title> 403 Forbidden\r\n</title></head>\n<body style="color: #444; margin:0;font: normal 14px/20px Arial, Helvetica, sans-serif; height:100%; background-color: #fff;">\n<div style="height:auto; min-height:100%; ">     <div style="text-align: center; width:800px; margin-left: -400px; position:absolute; top: 30%; left:50%;">\n        <h1 style="margin:0; font-size:150px; line-height:150px; font-weight:bold;">403</h1>\n<h2 style="margin-top:20px;font-size: 30px;">Forbidden\r\n</h2>\n<p>Access to this resource on the server is denied!</p>\n</div></div><div style="color:#f0f0f0; font-size:12px;margin:auto;padding:0px 30px 0px 30px;position:relative;clear:both;height:100px;margin-top:-101px;background-color:#474747;border-top: 1px solid rgba(0,0,0,0.15);box-shadow: 0 1px 0 rgba(255, 255, 255, 0.3) inset;">\n<br>Proudly powered by  <a style="color:#fff;" href="http://www.litespeedtech.com/error-page">LiteSpeed Web Server</a><p>Please be advised that LiteSpeed Technologies Inc. is not a web hosting company and, as such, has no control over content found on this site.</p></div></body></html>\n'

# %% [markdown]
# So the content of the page at the URL requested is now contained in a text string, and we can analyse it at our leisure.
#
# To do anything serious we probably need to request not just fixed web pages, but ones with associated search parameters. This is also easy with `requests`.

# %%
tommys = requests.get('https://tommys.co.nz', params={'action': 'epl_search', 
                                                      'property_address': 'wellington', 
                                                      'post_type': 'property',
                                                      'property_status': 'current'})

# %%
tommys.text
# Out:
# '<!DOCTYPE html>\n<!--[if IE 9 ]> <html lang="en-NZ" prefix="og: http://ogp.me/ns#" class="ie9 loading-site no-js"> <![endif]-->\n<!--[if IE 8 ]> <html lang="en-NZ" prefix="og: http://ogp.me/ns#" class="ie8 loading-site no-js"> <![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--><html lang="en-NZ" prefix="og: http://ogp.me/ns#" class="loading-site no-js"> <!--<![endif]-->\n<head>\n\t<meta charset="UTF-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n\n\t<link rel="profile" href="https://gmpg.org/xfn/11" />\n\t<link rel="pingback" href="https://www.tommys.co.nz/xmlrpc.php" />\n\n\t<script>(function(html){html.className = html.className.replace(/\\bno-js\\b/,\'js\')})(document.documentElement);</script>\n<title>Properties Archive - Tommy&#039;s Real Estate</title>\n\n<!-- This site is optimized with the Yoast SEO Premium plugin v7.2 - https://yoast.com/wordpress/plugins/seo/ -->\n<link rel="canonical" href="https://www.tommys.co.nz/property/" />\n<link rel="next" href="https://www.tommys.co.nz/property/page/2/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="object" />\n<meta property="og:title" content="Properties Archive - Tommy&#039;s Real Estate" />\n<meta property="og:url" content="https://www.tommys.co.nz/property/" />\n<meta property="og:site_name" content="Tommy&#039;s Real Estate" />\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:title" content="Properties Archive - Tommy&#039;s Real Estate" />\n<script type=\'application/ld+json\'>{"@context":"https:\\/\\/schema.org","@type":"Organization","url":"https:\\/\\/www.tommys.co.nz\\/","sameAs":["https:\\/\\/web.facebook.com\\/TommysWLG\\/?hc_ref=SEARCH&fref=nf&_rdc=1&_rdr","https:\\/\\/www.instagram.com\\/tommyswellington\\/"],"@id":"#organization","name":"Tommys Real Estate","logo":"https:\\/\\/www.tommys.co.nz\\/wp-content\\/uploads\\/2018\\/03\\/logo-tommys.png"}</script>\n<!-- / Yoast SEO Premium plugin. -->\n\n<link rel=\'dns-prefetch\' href=\'//code.jquery.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.tommys.co.nz\' />\n<link rel=\'dns-prefetch\' href=\'//maps.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//js.hs-scripts.com\' />\n<link rel=\'dns-prefetch\' href=\'//use.fontawesome.com\' />\n<link rel=\'dns-prefetch\' href=\'//cdn.jsdelivr.net\' />\n<link rel=\'dns-prefetch\' href=\'//addevent.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Tommy&#039;s Real Estate &raquo; Feed" href="https://www.tommys.co.nz/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Tommy&#039;s Real Estate &raquo; Comments Feed" href="https://www.tommys.co.nz/comments/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Tommy&#039;s Real Estate &raquo; Properties Feed" href="https://www.tommys.co.nz/property/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/11\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/11\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/www.tommys.co.nz\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=4.9.13"}};\n\t\t\t!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,561 ...

# %% [markdown]
# How did I figure out what parameters to send the site? These are encoded in the extended URL that you see when you've done a search on a website. For example

# %%
mightyape = requests.get('https://www.mightyape.co.nz/search', params={'q': 'board games', 'page': 1})

# %% [markdown]
# You can check that the correct URL was sent

# %%
mightyape.url
# Out:
# 'https://www.mightyape.co.nz/search?q=board+games&page=1'

# %% [markdown]
# ### Now pick the data apart
# I had a look at the Tommy's web page before, and figured out that the addresses are in a CSS selector called `".epl-template-tommys-one .property-address"`. In theory I can use this information to extract only that information from the mess of nonsense in the Tommy's HTML above.

# %%
result = BeautifulSoup(tommys.text)

# %% [markdown]
# This has returned a `BeautifulSoup` object that can parse HTML just like a web browser does.

# %%
type(result)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# To see how smart it is, we can ask it to make the mess we saw above prettier, and easier to read. Note that I am only asking for the first 1000 characters to save space.

# %%
print(result.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <!--[if IE 9 ]> <html lang="en-NZ" prefix="og: http://ogp.me/ns#" class="ie9 loading-site no-js"> <![endif]-->
# <!--[if IE 8 ]> <html lang="en-NZ" prefix="og: http://ogp.me/ns#" class="ie8 loading-site no-js"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <html class="loading-site no-js" lang="en-NZ" prefix="og: http://ogp.me/ns#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.tommys.co.nz/xmlrpc.php" rel="pingback"/>
#   <script>
#    (function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);
#   </script>
#   <title>
#    Properties Archive - Tommy's Real Estate
#   </title>
#   <!-- This site is optimized with the Yoast SEO Premium plugin v7.2 - https://yoast.com/wordpress/plugins/seo/ -->
#   <link href="https://www.tommys.co.nz/property/" rel="c

# %% [markdown]
# The main thing we need to be able to do, is to use `BeautifulSoup` to select only the elements we are interested in. It can make selections using HTML tags, HTML attributes or CSS selectors (named classes or ids). So... for example, to get all links on a page...

# %%
result.select('a')
# Out:
# [<a class="skip-link screen-reader-text" href="#main">Skip to content</a>,
#  <a href="https://www.tommys.co.nz/" rel="home" title="Tommy's Real Estate - Striving for outstanding service – Buying a home or selling your home, Talk to Tommy's">
#  <img alt="Tommy's Real Estate" class="header_logo header-logo" height="75" src="https://www.tommys.co.nz/wp-content/uploads/2019/09/Logo-RE-Full.png" width="200"/><img alt="Tommy's Real Estate" class="header-logo-dark" height="75" src="https://www.tommys.co.nz/wp-content/uploads/2019/09/Logo-RE-Full.png" width="200"/></a>,
#  <a aria-controls="main-menu" aria-expanded="false" class="is-small" data-bg="main-menu-overlay" data-color="" data-open="#main-menu" data-pos="right" href="#">
#  <i class="icon-menu"></i>
#  </a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/">Home</a>,
#  <a class="nav-top-link" href="#">Sell<i class="icon-angle-down"></i></a>,
#  <a href="https://www.tommys.co.nz/selling/">Selling</a>,
#  <a href="https://www.tommys.co.nz/marketing/">Marketing</a>,
#  <a href="https://www.tommys.co.nz/customer-success/">Customer Success Stories</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/buying/">Buy</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/developments/">Developments</a>,
#  <a class="nav-top-link" href="/agents/">Agents<i class="icon-angle-down"></i></a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TWLG001">Wellington City Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=THV001">Hutt Valley Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TMANA001">Mana/Whitby Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TKAPI001">Kapiti Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TWAIR001">Wairarapa Agents</a>,
#  <a class="nav-top-link" href="https://tommysrentals.co.nz/" target="_blank">Rent</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/community">Community</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/blog/">Blog</a>,
#  <a class="nav-top-link" href="#">Resources<i class="icon-angle-down"></i></a>,
#  <a href="https://www.tommys.co.nz/newsroom/">Newsroom</a>,
#  <a href="https://www.tommys.co.nz/resources/">Resources</a>,
#  <a href="https://www.tommys.co.nz/neighbourhoodhub/">Neighbourhood Hub</a>,
#  <a class="button primary is-medium" href="https://www.tommys.co.nz/market-appraisal/" style="border-radius:5px;">
#  <span>Book a free appraisal</span>
#  </a>,
#  <a class="is-small" href="#"><i class="icon-search"></i></a>,
#  <a class="button primary verum-search-filter-modal-btn"><span>Search</span></a>,
#  <a class="" href="/properties/">Properties</a>,
#  <a href="/properties/">Residential</a>,
#  <a class="all-listings-tab" href="javascript:">All Listings</a>,
#  <a class="all-listings-tab" href="javascript:">ALL LISTINGS</a>,
#  <a class="open-homes-tab" href="/properties/?property_category_type=openhomes">OPEN HOMES</a>,
#  <a class="sold-listings-tab" href="">SOLD</a>,
#  <a href="https://www.tommys.co.nz/property/4-52-russell-terrace-berhampore-wellington-6023/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/676545_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="477829"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">10</span></span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/4-52-russell-terrace-berhampore-wellington-6023/">SUPER STARTER...</a>,
#  <a href="https://www.tommys.co.nz/property/4-52-russell-terrace-berhampore-wellington-6023/">
#  <p class="street-name-number">4/52 Russell Terrace</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Berhampore / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/35-upper-watt-street-wadestown-wellington-6012/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/670902_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="471036"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">19</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">RV $1,860,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/35-upper-watt-street-wadestown-wellington-6012/">MAGNIFICENT HARBOUR VIEWS,...</a>,
#  <a href="https://www.tommys.co.nz/property/35-upper-watt-street-wadestown-wellington-6012/">
#  <p class="street-name-number">35 Upper Watt Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Wadestown / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/8b-131-abel-smith-street-aro-valley-wellington-6011/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/653617_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="479998"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">11</span></span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/8b-131-abel-smith-street-aro-valley-wellington-6011/">CITY SANCTUARY WITH STUNNI...</a>,
#  <a href="https://www.tommys.co.nz/property/8b-131-abel-smith-street-aro-valley-wellington-6011/">
#  <p class="street-name-number">8B/131 Abel Smith Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Aro Valley / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/12a-mairangi-road-wadestown-wellington-6012/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/675553_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="477374"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">18</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $1,495,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/12a-mairangi-road-wadestown-wellington-6012/">CONTEMPORARY LIVING IN WAD...</a>,
#  <a href="https://www.tommys.co.nz/property/12a-mairangi-road-wadestown-wellington-6012/">
#  <p class="street-name-number">12A Mairangi Road</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Wadestown / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/13a-mahoe-street-tawa-wellington-5028/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span><span class="status-sticker open">Open Home</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/675845_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="473166"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">22</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $645,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/13a-mahoe-street-tawa-wellington-5028/">MORE THAN MEETS THE EYE!...</a>,
#  <a href="https://www.tommys.co.nz/property/13a-mahoe-street-tawa-wellington-5028/">
#  <p class="street-name-number">13a Mahoe Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Tawa / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/199a-helston-road-paparangi-wellington-6037-2/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/676417_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="477494"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">16</span></span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/199a-helston-road-paparangi-wellington-6037-2/">THE PERFECT START!...</a>,
#  <a href="https://www.tommys.co.nz/property/199a-helston-road-paparangi-wellington-6037-2/">
#  <p class="street-name-number">199A Helston Road</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Paparangi / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/63-hector-street-seatoun-wellington-6022/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/673722_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="468834"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">20</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $1,795,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/63-hector-street-seatoun-wellington-6022/">THE ULTIMATE FAMILY HOME...</a>,
#  <a href="https://www.tommys.co.nz/property/63-hector-street-seatoun-wellington-6022/">
#  <p class="street-name-number">63 Hector Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Seatoun / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/22-sheridan-terrace-johnsonville-wellington-6037/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/664463_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="448031"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">17</span></span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/22-sheridan-terrace-johnsonville-wellington-6037/">SUPERB SUN, VIEWS &amp; PRIVAC...</a>,
#  <a href="https://www.tommys.co.nz/property/22-sheridan-terrace-johnsonville-wellington-6037/">
#  <p class="street-name-number">22 Sheridan Terrace</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Johnsonville / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/65-waitoa-road-hataitai-wellington-6021/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/674776_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="474317"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">17</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $645,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/65-waitoa-road-hataitai-wellington-6021/">COSY HATAITAI COTTAGE...</a>,
#  <a href="https://www.tommys.co.nz/property/65-waitoa-road-hataitai-wellington-6021/">
#  <p class="street-name-number">65 Waitoa Road</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Hataitai / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/9-178-wakefield-street-te-aro-wellington-6011-2/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span><span class="status-sticker open">Open Home</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/673021_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="467726"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">13</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $499,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/9-178-wakefield-street-te-aro-wellington-6011-2/">FUNKY INNER CITY LIVING...</a>,
#  <a href="https://www.tommys.co.nz/property/9-178-wakefield-street-te-aro-wellington-6011-2/">
#  <p class="street-name-number">9/178 Wakefield Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Te Aro / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/14-trevor-terrace-newtown-wellington-6021/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/676487_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="474285"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">16</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $895,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/14-trevor-terrace-newtown-wellington-6021/">SUNNY AND CENTRAL...</a>,
#  <a href="https://www.tommys.co.nz/property/14-trevor-terrace-newtown-wellington-6021/">
#  <p class="street-name-number">14 Trevor Terrace</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Newtown / Wellington</span></p> </a>,
#  <a href="https://www.tommys.co.nz/property/61-ellesmere-aveune-miramar-wellington-6022/">
#  <div class="epl-blog-image">
#  <div class="epl-stickers-wrapper">
#  <span class="status-sticker new">Just Listed</span><span class="status-sticker open">Open Home</span> </div>
#  <img alt="" class="teaser-left-thumb wp-post-image" height="200" src="https://www.tommys.co.nz/wp-content/uploads/2020/02/676273_web.jpg-300x200.jpeg" width="300"/>
#  </div>
#  </a>,
#  <a class="photo-gallery margin-left-b galleryOpenBtn" data-postid="477301"><span class="photo-gallery-wrapper"><img src="/wp-content/themes/flatsome-child/img/image_gallery_icon.png"/><span class="photo-gallery-count">22</span></span></a>,
#  <a class="property-price-wrapper margin-left-c"><span class="property-price">BEO $1,095,000</span></a>,
#  <a class="tmy-green-text" href="https://www.tommys.co.nz/property/61-ellesmere-aveune-miramar-wellington-6022/">IS THIS THE BEST BACKYARD ...</a>,
#  <a href="https://www.tommys.co.nz/property/61-ellesmere-aveune-miramar-wellington-6022/">
#  <p class="street-name-number">61 Ellesmere Aveune</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Miramar / Wellington</span></p> </a>,
#  <a class="page larger" href="https://www.tommys.co.nz/page/2/?action=epl_search&amp;property_address=wellington&amp;post_type=property&amp;property_status=current">2</a>,
#  <a class="page larger" href="https://www.tommys.co.nz/page/3/?action=epl_search&amp;property_address=wellington&amp;post_type=property&amp;property_status=current">3</a>,
#  <a class="page larger" href="https://www.tommys.co.nz/page/4/?action=epl_search&amp;property_address=wellington&amp;post_type=property&amp;property_status=current">4</a>,
#  <a class="page larger" href="https://www.tommys.co.nz/page/5/?action=epl_search&amp;property_address=wellington&amp;post_type=property&amp;property_status=current">5</a>,
#  <a class="nextpostslink" href="https://www.tommys.co.nz/page/2/?action=epl_search&amp;property_address=wellington&amp;post_type=property&amp;property_status=current" rel="next">NEXT</a>,
#  <a class="" href="http://www.nzrealtors.co.nz/" target="_blank"> <div class="img-inner dark">
#  <img alt="NZ realtor network Logo (Transparent)" class="attachment-large size-large" height="90" src="https://www.tommys.co.nz/wp-content/uploads/2018/06/NZ-realtor-network-Transparent.png" width="272"/>
#  </div>
#  </a>,
#  <a class="" href="http://www.moneybox.co.nz/" target="_blank"> <div class="img-inner dark">
#  <img alt="Money Box Logo (Transparent Logo)" class="attachment-large size-large" height="90" src="https://www.tommys.co.nz/wp-content/uploads/2018/06/Money-Box-Transparent-Logo.png" width="272"/>
#  </div>
#  </a>,
#  <a class="" href="https://www.orbitremit.com/" target="_blank"> <div class="img-inner dark">
#  <img alt="Orbit Remit Logo (Transparent)" class="attachment-large size-large" height="90" src="https://www.tommys.co.nz/wp-content/uploads/2018/06/Orbit-Remit-Transparent.png" width="272"/>
#  </div>
#  </a>,
#  <a href="/selling/" rel="follow">Sell </a>,
#  <a href="/buying/" rel="follow">Buy</a>,
#  <a href="http://www.tommys.co.nz/developments">Developments</a>,
#  <a href="https://www.tommys.co.nz/customer-success/" rel="follow">Customer Success Stories</a>,
#  <a href="http://www.tommys.co.nz/marketing">Marketing</a>,
#  <a href="http://www.tommys.co.nz/blog">Blog</a>,
#  <a href="https://www.tommys.co.nz/market-appraisal/">Free Appraisal</a>,
#  <a href="/neighbourhoodhub/" rel="follow">Neighbourhood</a>,
#  <a href="/about/" rel="follow">About Us</a>,
#  <a href="https://www.tommys.co.nz/resources/">Resources</a>,
#  <a href="/complaints/" rel="follow">Complaints </a>,
#  <a href="/faqs/" rel="follow">FAQS </a>,
#  <a href="/privacy/" rel="follow">Privacy </a>,
#  <a href="/community/" rel="follow">Community </a>,
#  <a href="/offices/" rel="follow">Offices </a>,
#  <a href="/agents/?agent_office_location=TWLG001" rel="follow">Agents - Wellington </a>,
#  <a href="/agents/?agent_office_location=THV001" rel="follow">Agents - Hutt Valley </a>,
#  <a href="/agents/?agent_office_location=TMANA001" rel="follow">Agents - Mana/Tawa</a>,
#  <a href="/agents/?agent_office_location=TKAPI001" rel="follow">Agents - Kapiti</a>,
#  <a href="/agents/?agent_office_location=TWAIR001">Agents - Wairarapa</a>,
#  <a href="/contact/" rel="follow">Contact us</a>,
#  <a href="http://www.tommys.co.nz/press-release">Newsroom</a>,
#  <a href="https://www.verum.nz" rel="noopener" target="_blank">Verum</a>,
#  <a href="https://www.tommys.co.nz/contact/">Contact</a>,
#  <a href="https://www.tommys.co.nz/about/">About Us</a>,
#  <a href="https://www.tommys.co.nz/faqs/">Faqs</a>,
#  <a href="https://www.tommys.co.nz/privacy/">Privacy</a>,
#  <a class="back-to-top button invert plain is-outline hide-for-medium icon circle fixed bottom z-1" href="#top" id="top-link"><i class="icon-angle-up"></i></a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/">Home</a>,
#  <a class="nav-top-link" href="#">Sell</a>,
#  <a href="https://www.tommys.co.nz/selling/">Selling</a>,
#  <a href="https://www.tommys.co.nz/marketing/">Marketing</a>,
#  <a href="https://www.tommys.co.nz/customer-success/">Customer Success Stories</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/buying/">Buy</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/developments/">Developments</a>,
#  <a class="nav-top-link" href="/agents/">Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TWLG001">Wellington City Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=THV001">Hutt Valley Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TMANA001">Mana/Whitby Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TKAPI001">Kapiti Agents</a>,
#  <a href="https://www.tommys.co.nz/agents/?agent_office_location=TWAIR001">Wairarapa Agents</a>,
#  <a class="nav-top-link" href="https://tommysrentals.co.nz/" target="_blank">Rent</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/community">Community</a>,
#  <a class="nav-top-link" href="https://www.tommys.co.nz/blog/">Blog</a>,
#  <a class="nav-top-link" href="#">Resources</a>,
#  <a href="https://www.tommys.co.nz/newsroom/">Newsroom</a>,
#  <a href="https://www.tommys.co.nz/resources/">Resources</a>,
#  <a href="https://www.tommys.co.nz/neighbourhoodhub/">Neighbourhood Hub</a>,
#  <a class="button primary is-medium" href="https://www.tommys.co.nz/market-appraisal/" style="border-radius:5px;">
#  <span>Book a free appraisal</span>
#  </a>]

# %% [markdown]
# That is way too much information. We can refine searches by specifying classes and other aspects of the tags of interest.

# %%
result.select('div.property-address')
# Out:
# [<div class="property-address">
#  <a href="https://www.tommys.co.nz/property/4-52-russell-terrace-berhampore-wellington-6023/">
#  <p class="street-name-number">4/52 Russell Terrace</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Berhampore / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/35-upper-watt-street-wadestown-wellington-6012/">
#  <p class="street-name-number">35 Upper Watt Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Wadestown / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/8b-131-abel-smith-street-aro-valley-wellington-6011/">
#  <p class="street-name-number">8B/131 Abel Smith Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Aro Valley / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/12a-mairangi-road-wadestown-wellington-6012/">
#  <p class="street-name-number">12A Mairangi Road</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Wadestown / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/13a-mahoe-street-tawa-wellington-5028/">
#  <p class="street-name-number">13a Mahoe Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Tawa / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/199a-helston-road-paparangi-wellington-6037-2/">
#  <p class="street-name-number">199A Helston Road</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Paparangi / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/63-hector-street-seatoun-wellington-6022/">
#  <p class="street-name-number">63 Hector Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Seatoun / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/22-sheridan-terrace-johnsonville-wellington-6037/">
#  <p class="street-name-number">22 Sheridan Terrace</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Johnsonville / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/65-waitoa-road-hataitai-wellington-6021/">
#  <p class="street-name-number">65 Waitoa Road</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Hataitai / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/9-178-wakefield-street-te-aro-wellington-6011-2/">
#  <p class="street-name-number">9/178 Wakefield Street</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Te Aro / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/14-trevor-terrace-newtown-wellington-6021/">
#  <p class="street-name-number">14 Trevor Terrace</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Newtown / Wellington</span></p> </a>
#  </div>,
#  <div class="property-address">
#  <a href="https://www.tommys.co.nz/property/61-ellesmere-aveune-miramar-wellington-6022/">
#  <p class="street-name-number">61 Ellesmere Aveune</p> <p class="suburb-region"><span class="location-icon"><img src="/wp-content/themes/flatsome-child/img/location_icon.png"/></span><span class="sub-reg">Miramar / Wellington</span></p> </a>
#  </div>]

# %% [markdown]
# Now we are getting warm!

# %%
for element in result.select('div.property-address'):
    print(element.text)
# Out:
# 4/52 Russell Terrace Berhampore / Wellington
#
#
#
# 35 Upper Watt Street Wadestown / Wellington
#
#
#
# 8B/131 Abel Smith Street Aro Valley / Wellington
#
#
#
# 12A Mairangi Road Wadestown / Wellington
#
#
#
# 13a Mahoe Street Tawa / Wellington
#
#
#
# 199A Helston Road Paparangi / Wellington
#
#
#
# 63 Hector Street Seatoun / Wellington
#
#
#
# 22 Sheridan Terrace Johnsonville / Wellington
#
#
#
# 65 Waitoa Road Hataitai / Wellington
#
#
#
# 9/178 Wakefield Street Te Aro / Wellington
#
#
#
# 14 Trevor Terrace Newtown / Wellington
#
#
#
# 61 Ellesmere Aveune Miramar / Wellington

# %% [markdown]
# Looking a bit more closely at the content, we might do even better with

# %%
for element in result.select('p.street-name-number'):
    print(element.text)
# Out:
# 4/52 Russell Terrace
# 35 Upper Watt Street
# 8B/131 Abel Smith Street
# 12A Mairangi Road
# 13a Mahoe Street
# 199A Helston Road
# 63 Hector Street
# 22 Sheridan Terrace
# 65 Waitoa Road
# 9/178 Wakefield Street
# 14 Trevor Terrace
# 61 Ellesmere Aveune

# %% [markdown]
# So, that is the first page of results. How do we get more? Going back to the website, we can see that there are links at the bottom of the search results to other pages, which cause the link to change such that the URL has added to it `/page/n` where n is a page number. Before we go mad, we should have a way to slow our tool down.

# %%
import time # Now there's a weird command to issue...

# %% [markdown]
# And here we are:

# %%
addresses = []
# Notice we have a loop starting from 1 and going to 10, not 0 to 9
for i in range(1, 11):
    page = requests.get('https://tommys.co.nz/page/' + str(i) + '/', params={'action': 'epl_search', 
                                                                       'property_address': 'wellington', 
                                                                       'post_type': 'property',
                                                                       'property_status': 'current'})
    print(page.url) # just for some reassurance
    pagecontent = BeautifulSoup(page.text)
    # add the results to our empty list
    for e in pagecontent.select('p.street-name-number'):
        addresses.append(e.text)
    time.sleep(1)
# Out:
# https://www.tommys.co.nz/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/2/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/3/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/4/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/5/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/6/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/7/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/8/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/9/?action=epl_search&property_address=wellington&post_type=property&property_status=current
# https://www.tommys.co.nz/page/10/?action=epl_search&property_address=wellington&post_type=property&property_status=current

# %%
addresses
# Out:
# ['4/52 Russell Terrace',
#  '35 Upper Watt Street',
#  '8B/131 Abel Smith Street',
#  '12A Mairangi Road',
#  '13a Mahoe Street',
#  '199A Helston Road',
#  '63 Hector Street',
#  '22 Sheridan Terrace',
#  '65 Waitoa Road',
#  '9/178 Wakefield Street',
#  '14 Trevor Terrace',
#  '61 Ellesmere Aveune',
#  '53 Catherine Crescent',
#  '2J/21 Rugby Street',
#  '104 Dixon Street',
#  '6 Linwood Way',
#  '2/15 Frederick Street',
#  '32 McColl Street',
#  '4F/242 Taranaki Street',
#  '16/15 Roxburgh Street',
#  '5A/25 Cuba Street',
#  '19 Shotter Street',
#  '57 Anne Street',
#  '5 Chelsea Street',
#  '14A Mascot Street',
#  '15B Mitchell Street',
#  '9 Turville Crescent',
#  '15B Perth Street',
#  '21 Bendigo Grove',
#  '2 Footscray Avenue',
#  '67 Weld Street',
#  '54 Severn Street',
#  '110 Ruskin Road',
#  '2A/7 Clyde Quay Wharf',
#  '2/99 Dixon Street',
#  '3E/255 The Terrace',
#  '10 Plunket Street',
#  '411/107 Thorndon Quay',
#  '17 Brighton Street',
#  '114/80 Riddiford Street',
#  '2D/25 Cuba Street',
#  '7 Millward Street',
#  '102 Awarua Street',
#  '734 Makara Road',
#  '1/279 Karaka Bay Road',
#  '303/20 Hanson Street',
#  '4/56 Tanera Crescent',
#  '81 Palliser Road',
#  '13A Marjory Close',
#  '7/93A Kelburn Parade',
#  '83 Sar Street',
#  '10A Buxton Avenue',
#  '304/107 Thorndon Quay',
#  '3A Linwood Way',
#  '170 Fraser Ave',
#  '59 Tirangi Road',
#  '51A Waipapa Road',
#  '6 Avon Street',
#  '2A Radnall Way',
#  '30 Mornington Road',
#  '20 Raumati Terrace',
#  '128A Tasman Street',
#  '11A Hillary Street',
#  '2 Cook Street',
#  'DK3.5 (Aro)/188/208 Victoria Street',
#  'L2.5 (Aro)/188/208 Victoria Street',
#  'DK3 (Aro)/188/208 Victoria Street',
#  'L3 (Aro)/188/208 Victoria Street',
#  'LW3.5 (Aro)/188/208 Victoria Street',
#  '5 Epuni Street',
#  '31 Avon Street',
#  '65 Cecil Road',
#  '1105/166 Victoria Street',
#  '8/2 McFarlane Street',
#  '31 Avon Street',
#  '10 Lorne Street',
#  'H103/326 Evans Bay Parade',
#  '5/5 Tory Street',
#  '97 Taranaki Street (Tribeca)',
#  '97 Taranaki Street (Work x Live)',
#  '6 Orangi Kaupapa Road',
#  '2/212 Oriental Parade',
#  '19D-F Rangiora Avenue',
#  '160 Victoria Street',
#  '123/97 Taranaki Street']

# %% [markdown]
# That, believe it or not, is more or less all you need to know to scrape websites.
#
# For fun, you might see if you can do a similar search on one of the other property websites. Or maybe change the Tommy's search to look for 3 bedroom rentals.
#
# ### More
# There are other web scraping tools out there. One that is popular is [`scrapy`](https://scrapy.org/) a  framework for building web crawlers and scrapers, so it handles more of the complexities of multiple searches and so on.
#
# But really that's it! Potentially a useful tool for research projects.
